# %%
# Import Dependencies
import requests
import pandas as pd
import json
from splinter import Browser
from bs4 import BeautifulSoup as bs
from unicodedata import normalize
import numpy as np
import time
from io import StringIO

# %% [markdown]
# # Finding First Source #

# %%
# Get URL
first_url = "https://www.ncei.noaa.gov/access/billions/events-US-1980-2024.json"

# %%
# Read JSON
res = requests.get(first_url).json()

# %%
# Extract Necessary Data from JSON
res_data = res['data']

# %%
# Create a DataFrame from JSON
million_dollar_disasters = pd.DataFrame(res_data)

# %%
# Confirm number of rows in the data
len(million_dollar_disasters)
# Out:
# 383

# %%
# Look at one row of data
million_dollar_disasters.sample(1)
# Out:
#                                                   name      disaster  \
# 137  Southeast Tornadoes and Severe Weather (Februa...  Severe Storm
#
#       begDate   endDate  adjCost  unadjCost  deaths
# 137  20080205  20080206   1793.2     1211.6      57

# %%
# Export to CSV
million_dollar_disasters.to_csv('million_dollar_disasters.csv')

# %% [markdown]
# # Finding 2nd Source #

# %%
# Set up the browser
browser = Browser('chrome')

# %%
# Set URL & Visit URL
html = "https://public.opendatasoft.com/explore/dataset/openaq/table/?disjunctive.city&disjunctive.location&disjunctive.measurements_parameter&sort=measurements_lastupdated&refine.country_name_en=United+States"
browser.visit(html)

# %%
# Parse the data
html = browser.html
soup = bs(html, 'html.parser')

# %%
# Extract Header List for DataFrame columns
header_list = []
records_headers = soup.find_all('div',class_='odswidget-table__label')
for row in records_headers:
    header_list.append(row.text)
header_list
# Out:
# ['Country Label', 'Pollutant', 'Value', 'Unit', 'Last Updated', 'Source Name']

# %%
# Extract rows for DataFrame
row_list = []
n = 0
table = soup.find('tr')

for row in table:
    throwaway = soup.find('tr', class_= f'odswidget-table__internal-table-row record-{n}').find('td', class_="odswidget-table__cell").find('div', class_="odswidget-table__cell-container")
    values = [throwaway.findNext('div').text,
    throwaway.findNext('div').findNext('div').text,
    throwaway.findNext('div').findNext('div').findNext('div').text,
    throwaway.findNext('div').findNext('div').findNext('div').findNext('div').text,
    throwaway.findNext('div').findNext('div').findNext('div').findNext('div').findNext('div').text,
    throwaway.findNext('div').findNext('div').findNext('div').findNext('div').findNext('div').findNext('div').text]

    row_list.append(values)
    n += 1

# %%
# Create DataFrame
df_2 = pd.DataFrame(row_list, columns=header_list)
df_2
len(df_2)
# Out:
# 17

# %%
# Quit the browsing session
browser.quit()

# %% [markdown]
# Note: We were only able to extract 16 rows by scraping so we decided to go the JSON route.

# %% [markdown]
# # Finding 3rd Source #

# %%
# Define URL
third_url = "https://public.opendatasoft.com/api/records/1.0/search/?rows=100&disjunctive.city=true&disjunctive.location=true&disjunctive.measurements_parameter=true&sort=measurements_lastupdated&refine.country_name_en=United+States&start=0&fields=country_name_en,measurements_parameter,measurements_value,measurements_unit,measurements_lastupdated,measurements_sourcename&dataset=openaq&timezone=America%2FChicago&lang=en"

# %%
# Get the data
res_2 = requests.get(third_url).json()
res_2
# Out:
# {'nhits': 6051,
#  'parameters': {'dataset': 'openaq',
#   'lang': 'en',
#   'rows': 100,
#   'start': 0,
#   'sort': ['measurements_lastupdated'],
#   'refine': {'country_name_en': 'United States'},
#   'disjunctive': {'city': 'true',
#    'location': 'true',
#    'measurements_parameter': 'true'},
#   'format': 'json',
#   'timezone': 'America/Chicago',
#   'fields': ['country_name_en',
#    'measurements_parameter',
#    'measurements_value',
#    'measurements_unit',
#    'measurements_lastupdated',
#    'measurements_sourcename']},
#  'records': [{'datasetid': 'openaq',
#    'recordid': '1e2db59bc1c67d7e1f818ff0e4a5c4d5bfdb618f',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.037,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'O3',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '488082fdc2cce20bb0321437c9db425e35d8d3be',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 44.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM10',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '3ea4c3ca9e174f93072102484da3bab4fb0b45b2',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.001,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'NO2',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '6d48f911069b4de6d34b5bec7e942fb2a45c13e5',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 20.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM10',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'bd72bd2e262bc29e1870c931e8ef7f2d34ef08ab',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 4.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '588f6e41479db5f7edfc392d98247236a1c24465',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 16.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM10',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'c718821403413d6ecc70bb4ac6800f1b875a5b72',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.0002,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'SO2',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '7360d129ad764e1cd74b34597ffc7db8f78be129',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 4.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'f29ad8a5bbebbd61ebb8a0bdc21cb31942b84966',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.051,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'O3',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '33aaddbb47a5683b8fe08b2a6666d8c51f5e652a',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.041,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'O3',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'd04f1a979cf3e74d24f908ca79734187d54c687d',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.041,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'O3',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '5f4790be3bb9b72c75882b0a1ea312dfcaa21cb5',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 4.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '33990e08acb0f47206775b20d27843c8d0c6f34d',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.04,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'O3',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'e6aa428d745097af838e1d83373f16844e8e3ec6',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.053,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'O3',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'dd4e0bd7db6cfbdf413ffa83d697e5a33d211863',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.0004,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'NO',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '25e273b5b303e2ae41a907261994b6f3ecac056c',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 6.9,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '751172d39f19b916c2f664488f0212b83ede07e4',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 6.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'fd5be65d018c14dc6807df52ab0eccc0af12a2bc',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'SO2',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'a52d9ec23489b0401202366c9e035677940afcde',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.3,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'CO',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '48baae1be6e8f71f97e60127e2766ca9169b5389',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.0018,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'NO',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'e7d358fc45883d262507a522f3db940a99c7f177',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.0182,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'NO',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'ccb51cd81feca407275af41861befc3e9ba01e2f',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 24.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM10',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'f7eeaefdfd9190ccd52c592550807ad8f1caa6d9',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 27.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM10',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '899ccd231cbc6dac61c725fc343ede4f2199575d',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.001,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'SO2',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '4c2c1d5314b492ac0081e49394eaffca2b85c04e',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 5.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '915ab074a52b595f61b485a9b35ff595e2a33809',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 9.2,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '19715bdcab4c820e5854746515380c84cfb37e9f',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 3.7,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'e41461f6facee90ce7d28b4f266d9f2cf13c8729',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.059,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'O3',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'e52a7b3a79a6208a2fd1416a8137e82580bc0e79',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.05,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'O3',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'a6a2aebe457a5e0f15d562dae3d1f18b753f9741',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.028,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'O3',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'c8e59290b90d020901adf2a26e4af3bd52246e27',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.0001,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'SO2',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'e54667898b5505c101334f2c15846a50145344da',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 18.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '1ef2a24764ac7fe6abb199822057aea56cec2e8f',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 9.3,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '1c4cab552b90035491e24433095945ecd64cb723',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.077,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'O3',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid':

#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '0e0b75400e50690cc8a35adaacbcd5c5448e95c1',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 5.8,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '7a862a078192325cff4daf37c50874b5946e429f',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'NO',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'e016c2749508d672e6b6129164cdf2104a020899',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 6.4,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'f5bc6ee6ece9d120274d2c71002d3d62f8efbcf4',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.2,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'CO',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'fbea35a7f1e4c33d73391eb550672cd4d5690500',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 7.8,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '07a4bcf9b42a436709933d39b9947e3afc15169c',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.075,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'O3',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'a4d28036beff8cd2628ccf85290b09078b98760b',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 16.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '39b9fb91d1ba3017bb475ff911e38090f6f4e0be',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 42.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM10',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'd11ff7de4b60bb4fa62acb6033efe906840f911e',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 3.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'a614dfe40852cef25841e7f7d40a09635c64e3c7',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.031,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'O3',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '6a51c00894990a43eb9e69a2e8c088bedf46e778',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 4.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '8e743c7361f90c76b5a2a7dab32a3c1ff7043fb2',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 11.3,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'd4f3904566330f20b15e75809545516f6602b32f',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.056,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'O3',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '30eca2e8797343607f94e0df2d0d619f9ad414d2',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 3.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'a386bb57f57eb5b58b89fe72d56843106711b9ae',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.0009,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'NOX',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '740350983067cf15cf50b03a45d038df9fe5315e',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.1,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'CO',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '941ac07dd02e83b7bf7eeaad3d42e70e2dea88d1',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 17.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM10',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '6b90ba8dfed6cace5ae1deffde74c2f8ddc7bd18',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 15.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM10',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'ae6e659e18ebd0dd017c12883ae8043dc7373e66',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.042,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'O3',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '6f6b4752f3622840d5d05deaa9978415d532c889',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 1.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'd5d7b0ec88c1cb789fa6fad9bf2da33f9fb76dbf',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 2.7,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM2.5',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '196835899ced1fa31cad3bdce042240b6aa638e1',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.0024,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'NOX',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': '295b85fe7b233f3789757ac3096440d1caf0f388',
#    'fields': {'measurements_unit': 'µg/m³',
#     'measurements_value': 12.0,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'PM10',
#     'country_name_en': 'United States'}},
#   {'datasetid': 'openaq',
#    'recordid': 'aed039ad45a08cf37b784561990348a51e9752c4',
#    'fields': {'measurements_unit': 'ppm',
#     'measurements_value': 0.0016,
#     'measurements_sourcename': 'AirNow',
#     'measurements_lastupdated': '2023-05-30T18:00:00-05:00',
#     'measurements_parameter': 'NOX',
#     'country_name_en': 'United States'}}],
#  'facet_groups': [{'name': 'country_name_en',
#    'facets': [{'name': 'United States',
#      'count': 6051,
#      'state': 'refined',
#      'path': 'United States'}]}]}

# %%
# Drill down to data needed
res_2_data_list = []
res_2_data = res_2['records']
for record in res_2_data:
    record = res_2['records'][2]['fields']
    res_2_data_list.append(record)

# %%
# Create DataFrame
air_pollution_df = pd.DataFrame(res_2_data_list)
air_pollution_df.sample(1)
# Out:
#    measurements_unit  measurements_value measurements_sourcename  \
# 12               ppm               0.001                  AirNow
#
#      measurements_lastupdated measurements_parameter country_name_en
# 12  2023-05-30T18:00:00-05:00                    NO2   United States

# %%
# Verify number of rows in DataFrame
len(air_pollution_df)
# Out:
# 100

# %%
# Export to CSV
air_pollution_df.to_csv('air_pollution_df.csv')

# %% [markdown]
# Note: We extracted the limit of 100 lines only for this assignment due to time constraints
